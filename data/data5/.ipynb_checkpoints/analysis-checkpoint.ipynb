# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
data = np.load("data.npy")
scores = np.load("scores.npy")
performance = np.load("performance.npy")
df = pd.DataFrame(data)
df = df[(df.T != 0).any()]
df.reset_index(inplace = True, drop = True)
df
# Out:
#              0          1          2          3
# 0     0.310024   0.092022   0.101165   0.000000
# 1     0.098527   0.000000   0.000000   0.000000
# 2     0.000000   0.065410   0.000000   0.000000
# 3     0.089797   0.013951   0.000000   0.000000
# 4     0.386515   0.403353   0.401105   0.689113
# ..         ...        ...        ...        ...
# 373 -30.507513 -25.285114 -19.900000 -25.516827
# 374 -52.123391 -50.728454 -48.964084 -52.397284
# 375 -36.142485 -37.687221 -42.151325 -39.391866
# 376 -37.591183 -36.205926 -28.779292 -38.488322
# 377 -39.535185 -41.068227 -42.116162 -39.403990
#
# [378 rows x 4 columns]

# %%
plt.scatter(x=range(len(scores)), y=scores, s=1)

# %%
df_scores = pd.DataFrame(scores)
df_scores.rolling(40).mean().plot()

# %%
print(f"Average:{np.average(performance)}")
df_performance = pd.DataFrame(performance)
df_performance.rolling(200).mean().plot()
# Out:
# Average:8.7166
