# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
data = np.load("data.npy")
scores = np.load("scores.npy")
performance = np.load("performance.npy")
df = pd.DataFrame(data)
df = df[(df.T != 0).any()]
df.reset_index(inplace = True, drop = True)
df
# Out:
#              0           1           2           3
# 0     0.161433    0.300949    0.186868    0.296690
# 1     0.043444    0.046996    0.161575    0.000000
# 2     0.046415    0.102830    0.232420    0.103750
# 3     0.102677    0.000000    0.000000    0.056299
# 4     0.367914    0.365561    0.359423    0.568357
# ..         ...         ...         ...         ...
# 390 -92.809742  -87.084965  -86.359500  -93.513718
# 391 -98.108968 -102.328365 -104.385131 -105.527621
# 392 -73.730017  -82.628087  -73.995348  -73.522709
# 393 -91.892544  -84.111067  -82.534565  -89.876265
# 394 -93.504465  -92.578882  -92.850265  -93.880702
#
# [395 rows x 4 columns]

# %%
plt.scatter(x=range(len(scores)), y=scores, s=1)

# %%
df_scores = pd.DataFrame(scores)
df_scores.rolling(40).mean().plot()

# %%
print(f"Average:{np.average(performance)}")
df_performance = pd.DataFrame(performance)
df_performance.rolling(200).mean().plot()
# Out:
# Average:26.9491
