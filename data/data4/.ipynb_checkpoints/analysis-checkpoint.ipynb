# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
data = np.load("data.npy")
scores = np.load("scores.npy")
performance = np.load("performance.npy")
df = pd.DataFrame(data)
df = df[(df.T != 0).any()]
df.reset_index(inplace = True, drop = True)
df
# Out:
#               0           1           2           3
# 0      0.252548    0.062976    0.012926    0.000000
# 1      0.066493    0.004897    0.000000    0.015835
# 2     -0.001928    0.053196    0.000000    0.000000
# 3      0.068414    0.000000    0.000000    0.000000
# 4      0.329615    0.349160    0.213167    0.797583
# ..          ...         ...         ...         ...
# 394 -112.766254 -106.688074 -118.246711 -116.724119
# 395 -137.136313 -128.722326 -101.699205 -132.800052
# 396 -117.844792 -118.157345 -111.715950 -122.921990
# 397 -113.267366 -111.109502 -106.266839 -105.567674
# 398 -138.309078 -131.628881 -133.853146 -122.446609
#
# [399 rows x 4 columns]

# %%
plt.scatter(x=range(len(scores)), y=scores, s=1)

# %%
df_scores = pd.DataFrame(scores)
df_scores.rolling(40).mean().plot()

# %%
print(f"Average:{np.average(performance)}")
df_performance = pd.DataFrame(performance)
df_performance.rolling(200).mean().plot()
# Out:
# Average:20.4303
