# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
data = np.load("data.npy")
scores = np.load("scores.npy")
performance = np.load("performance.npy")
df = pd.DataFrame(data)
df = df[(df.T != 0).any()]
df.reset_index(inplace = True, drop = True)
df
# Out:
#              0          1          2          3
# 0     0.256390   0.256452   0.359439   0.356615
# 1     0.046651   0.084132   0.114109   0.000000
# 2     0.253957   0.036778   0.045228   0.144726
# 3     0.229596   0.041427   0.053344   0.041095
# 4     0.362473   0.356333   0.320660   0.666357
# ..         ...        ...        ...        ...
# 395 -86.184089 -91.872848 -87.604539 -86.547205
# 396 -89.753046 -84.598835 -83.930695 -89.241300
# 397 -75.457207 -73.716777 -82.194656 -75.717694
# 398 -77.242225 -81.611264 -75.685975 -75.911133
# 399 -81.881601 -78.200175 -59.203865 -78.525950
#
# [400 rows x 4 columns]

# %%
plt.scatter(x=range(len(scores)), y=scores, s=1)

# %%
df_scores = pd.DataFrame(scores)
df_scores.rolling(40).mean().plot()

# %%
print(f"Average:{np.average(performance)}")
df_performance = pd.DataFrame(performance)
df_performance.rolling(40).mean().plot()
# Out:
# Average:28.4874
